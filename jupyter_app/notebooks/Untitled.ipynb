# %%
import pandas as pd

# %%
path = "/data/processed/wine_raw_20251110_231331.csv"

df = pd.read_csv(path)

df
# Out:
#       FIXED_ACIDITY  VOLATILE_ACIDITY  CITRIC_ACID  RESIDUAL_SUGAR  CHLORIDES  \
# 0               1.0             1.100         1.20             1.3      1.400
# 1               3.0             4.100         5.40             4.3      4.400
# 2               8.0             8.100         8.40             8.3      8.400
# 3               7.4             0.700         0.00             1.9      0.076
# 4               7.8             0.880         0.00             2.6      0.098
# ...             ...               ...          ...             ...        ...
# 6400            6.2             0.600         0.08             2.0      0.090
# 6401            5.9             0.550         0.10             2.2      0.062
# 6402            6.3             0.510         0.13             2.3      0.076
# 6403            5.9             0.645         0.12             2.0      0.075
# 6404            6.0             0.310         0.47             3.6      0.067
#
# ...
